# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.colors as colors

import numpy as np
import xarray as xr

# %%
run_dir = '/glade/scratch/pel/mars_ne16_ne16_mg17_short/run/'
file = 'mars_ne16_ne16_mg17_short.cam.h1.0001-01-01-00000.nc'

ds = xr.open_dataset(run_dir+file)

# %%
ds.T.mean(dim='lon').plot(y='lev', yscale='log', 
                          yrange=[7,1e-10),col="time", col_wrap=4, robust=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [9], in <cell line: 1>()
# ----> 1 ds.T.mean(dim='lon').plot(y='lev', yscale='log',
#       2                           yrange=(7,1e-10),col="time", col_wrap=4, robust=True)
#
# File /glade/work/marsh/miniconda3/envs/default/lib/python3.9/site-packages/xarray/plot/plot.py:866, in _PlotMethods.__call__(self, **kwargs)
#     865 def __call__(self, **kwargs):
# --> 866     return plot(self._da, **kwargs)
#
# File /glade/work/marsh/miniconda3/envs/default/lib/python3.9/site-packages/xarray/plot/plot.py:332, in plot(darray, row, col, col_wrap, ax, hue, rtol, subplot_kws, **kwargs)
#     328     plotfunc = hist
#     330 kwargs["ax"] = ax
# --> 332 return plotfunc(darray, **kwargs)
#
# ...
